# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
#import data set and split the data into dependent and independent variables 
df = pd.read_csv("Salary_DataSet.csv")
x = df.iloc[:,0]
y = df.iloc[:,1]

# %%
##Training and Testing Data (divide the data into two part)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=0)

X_train = X_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)

X_train.shape
# Out:
# (21, 1)

# %%
X_train
# Out:
# array([[ 7.9],
#        [ 2.9],
#        [ 5.1],
#        [ 3.2],
#        [ 4.5],
#        [ 8.2],
#        [ 6.8],
#        [ 1.3],
#        [10.5],
#        [ 3. ],
#        [ 2.2],
#        [ 5.9],
#        [ 6. ],
#        [ 3.7],
#        [ 3.2],
#        [ 9. ],
#        [ 2. ],
#        [ 1.1],
#        [ 7.1],
#        [ 4.9],
#        [ 4. ]])

# %%
# regression 
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict([[6.5]])# prediction for a single value 
y_pred
# Out:
# array([87619.08970146])

# %%
y_pred = reg.predict(X_test)

# %%
print (y_pred)
print(y_test)
# Out:
# [ 40817.78327049 123188.08258899  65154.46261459  63282.41035735
#  115699.87356004 108211.66453108 116635.89968866  64218.43648597
#   76386.77615802]
# 2      37731
# 28    122391
# 13     57081
# 10     63218
# 26    116969
# 24    109431
# 27    112635
# 11     55794
# 17     83088
# Name: Salary, dtype: int64

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test , y_pred)
r2
# Out:
# 0.9740993407213511

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train ,reg.predict(X_train),color ="red")

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_train, reg.predict(X_train), color='blue')

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_test, reg.predict(X_test), color='blue')
