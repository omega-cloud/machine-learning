# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Poly_dataSet.csv")
X=df.iloc[:,0].values.reshape(-1,1)
y=df.iloc[:,1].values.reshape(-1,1)

# %%
# Out:
# array([[  45000],
#        [  50000],
#        [  60000],
#        [  80000],
#        [ 110000],
#        [ 150000],
#        [ 200000],
#        [ 300000],
#        [ 500000],
#        [1000000]], dtype=int64)

# %%
# Fitting Linear Regression to the dataset
from sklearn.ensemble import RandomForestRegressor

rf =RandomForestRegressor(n_estimators=10,random_state=0)
rf.fit(X,y)
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_10604\4149715192.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X,y)
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
rf.predict([[6.5]])
# Out:
# array([167000.])

# %%
r2= rf.score(X,y)
r2
# Out:
# 0.9704434230386582

# %%
# Visualising the Linear Regression results
plt.scatter(X, y, color = 'red')
plt.plot(X, rf.predict(X), color = 'blue')
plt.title('Truth or Bluff (SVR Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
